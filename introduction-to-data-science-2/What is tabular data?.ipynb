# %%
import pandas as pd

# %%
us_baby_names_1 = pd.read_csv("Exercise Files/us_baby_names_1.csv")

# %%
us_baby_names_2 = pd.read_csv("Exercise Files/us_baby_names_2.csv")

# %%
us_baby_names_1
# Out:
#             Id       Name  Year Gender  Count
# 0            1       Mary  1880      F   7065
# 1            2       Anna  1880      F   2604
# 2            3       Emma  1880      F   2003
# 3            4  Elizabeth  1880      F   1939
# 4            5     Minnie  1880      F   1746
# ...        ...        ...   ...    ...    ...
# 999994  999995     Treven  1986      M      7
# 999995  999996     Trevyn  1986      M      7
# 999996  999997     Tryone  1986      M      7
# 999997  999998     Tushar  1986      M      7
# 999998  999999       Tyan  1986      M      7
#
# [999999 rows x 5 columns]

# %%
us_baby_names_2
# Out:
#              Id     Name  Year Gender  Count
# 0       1000000    Tymel  1986      M      7
# 1       1000001    Tymon  1986      M      7
# 2       1000002   Tyrail  1986      M      7
# 3       1000003     Umer  1986      M      7
# 4       1000004    Usher  1986      M      7
# ...         ...      ...   ...    ...    ...
# 825429  1825429   Zykeem  2014      M      5
# 825430  1825430   Zymeer  2014      M      5
# 825431  1825431  Zymiere  2014      M      5
# 825432  1825432    Zyran  2014      M      5
# 825433  1825433    Zyrin  2014      M      5
#
# [825434 rows x 5 columns]

# %%
us_baby_names_2['Year']
# Out:
# 0         1986
# 1         1986
# 2         1986
# 3         1986
# 4         1986
#           ...
# 825429    2014
# 825430    2014
# 825431    2014
# 825432    2014
# 825433    2014
# Name: Year, Length: 825434, dtype: int64

# %%
us_baby_names_2['Year'] == 2014
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 825429     True
# 825430     True
# 825431     True
# 825432     True
# 825433     True
# Name: Year, Length: 825434, dtype: bool

# %%
us_baby_names_1['Year'] == 2014
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999994    False
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# Name: Year, Length: 999999, dtype: bool

# %%
us_baby_names_2.loc[us_baby_names_2['Year'] == 2014,:]
# Out:
#              Id      Name  Year Gender  Count
# 792390  1792390      Emma  2014      F  20799
# 792391  1792391    Olivia  2014      F  19674
# 792392  1792392    Sophia  2014      F  18490
# 792393  1792393  Isabella  2014      F  16950
# 792394  1792394       Ava  2014      F  15586
# ...         ...       ...   ...    ...    ...
# 825429  1825429    Zykeem  2014      M      5
# 825430  1825430    Zymeer  2014      M      5
# 825431  1825431   Zymiere  2014      M      5
# 825432  1825432     Zyran  2014      M      5
# 825433  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
us_babies_2014 = us_baby_names_2.loc[us_baby_names_2['Year'] == 2014,:]

# %%
us_babies_2014
# Out:
#              Id      Name  Year Gender  Count
# 792390  1792390      Emma  2014      F  20799
# 792391  1792391    Olivia  2014      F  19674
# 792392  1792392    Sophia  2014      F  18490
# 792393  1792393  Isabella  2014      F  16950
# 792394  1792394       Ava  2014      F  15586
# ...         ...       ...   ...    ...    ...
# 825429  1825429    Zykeem  2014      M      5
# 825430  1825430    Zymeer  2014      M      5
# 825431  1825431   Zymiere  2014      M      5
# 825432  1825432     Zyran  2014      M      5
# 825433  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
sorted_us_2014 = us_babies_2014.sort_values('Count', ascending = False)

# %%
sorted_us_2014
# Out:
#              Id    Name  Year Gender  Count
# 792390  1792390    Emma  2014      F  20799
# 792391  1792391  Olivia  2014      F  19674
# 811457  1811457    Noah  2014      M  19144
# 792392  1792392  Sophia  2014      F  18490
# 811458  1811458    Liam  2014      M  18342
# ...         ...     ...   ...    ...    ...
# 810562  1810562   Melba  2014      F      5
# 810561  1810561  Melaya  2014      F      5
# 810560  1810560     Mel  2014      F      5
# 810559  1810559   Mekhi  2014      F      5
# 825433  1825433   Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
sorted_us_2014.iloc[0:5]
# Out:
#              Id    Name  Year Gender  Count
# 792390  1792390    Emma  2014      F  20799
# 792391  1792391  Olivia  2014      F  19674
# 811457  1811457    Noah  2014      M  19144
# 792392  1792392  Sophia  2014      F  18490
# 811458  1811458    Liam  2014      M  18342

# %%
import glob

# %%
# get data file names
path = r'Exercise Files'
filenames = glob.glob(path + "/state_baby_names_*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
states_babies = pd.concat(dfs, ignore_index=True)

# %%
states_babies
# Out:
#               Id       Name  Year Gender State  Count
# 0        3999994      Perry  1960      M    OH    133
# 1        3999995       Kent  1960      M    OH    130
# 2        3999996        Ray  1960      M    OH    130
# 3        3999997        Ted  1960      M    OH    130
# 4        3999998   Clifford  1960      M    OH    128
# ...          ...        ...   ...    ...   ...    ...
# 5647421  2499991  Nicolette  1961      F    MI      5
# 5647422  2499992       Paul  1961      F    MI      5
# 5647423  2499993       Peri  1961      F    MI      5
# 5647424  2499994       Rana  1961      F    MI      5
# 5647425  2499995      Ranae  1961      F    MI      5
#
# [5647426 rows x 6 columns]

# %%
states_babies_2014 = states_babies.loc[states_babies['Year'] == 2014, :]

# %%
states_babies_2014
# Out:
#               Id     Name  Year Gender State  Count
# 49298    4049292     Liam  2014      M    OH    716
# 49299    4049293    Mason  2014      M    OH    666
# 49300    4049294     Noah  2014      M    OH    655
# 49301    4049295  William  2014      M    OH    598
# 49302    4049296   Carter  2014      M    OH    597
# ...          ...      ...   ...    ...   ...    ...
# 5614712  2467282    Lukas  2014      M    ME      5
# 5614713  2467283    Orion  2014      M    ME      5
# 5614714  2467284  Russell  2014      M    ME      5
# 5614715  2467285  Stephen  2014      M    ME      5
# 5614716  2467286    Trent  2014      M    ME      5
#
# [94148 rows x 6 columns]

# %%
ca_babies_2014 = states_babies_2014.loc[states_babies_2014['State'] == 'CA', :]

# %%
ca_babies_2014
# Out:
#              Id      Name  Year Gender State  Count
# 2208928  561496    Sophia  2014      F    CA   3162
# 2208929  561497  Isabella  2014      F    CA   2705
# 2208930  561498      Emma  2014      F    CA   2662
# 2208931  561499       Mia  2014      F    CA   2627
# 2208932  561500    Olivia  2014      F    CA   2407
# ...         ...       ...   ...    ...   ...    ...
# 2357658  710226    Zakary  2014      M    CA      5
# 2357659  710227   Zealand  2014      M    CA      5
# 2357660  710228      Ziad  2014      M    CA      5
# 2357661  710229    Zidane  2014      M    CA      5
# 2357662  710230     Ziyad  2014      M    CA      5
#
# [6903 rows x 6 columns]

# %%
sorted_ca_babies_2014 = ca_babies_2014.sort_values('Count', ascending = False)

# %%
sorted_ca_babies_2014
# Out:
#              Id      Name  Year Gender State  Count
# 2208928  561496    Sophia  2014      F    CA   3162
# 2354744  707312      Noah  2014      M    CA   2761
# 2208929  561497  Isabella  2014      F    CA   2705
# 2354745  707313     Jacob  2014      M    CA   2692
# 2208930  561498      Emma  2014      F    CA   2662
# ...         ...       ...   ...    ...   ...    ...
# 2212726  565294    Marvel  2014      F    CA      5
# 2212727  565295     Masyn  2014      F    CA      5
# 2212728  565296  Mathilda  2014      F    CA      5
# 2212729  565297    Mattea  2014      F    CA      5
# 2357662  710230     Ziyad  2014      M    CA      5
#
# [6903 rows x 6 columns]

# %%
sorted_ca_babies_2014[0:5]
# Out:
#              Id      Name  Year Gender State  Count
# 2208928  561496    Sophia  2014      F    CA   3162
# 2354744  707312      Noah  2014      M    CA   2761
# 2208929  561497  Isabella  2014      F    CA   2705
# 2354745  707313     Jacob  2014      M    CA   2692
# 2208930  561498      Emma  2014      F    CA   2662

# %%
sorted_ca_babies_2014.iloc[0:5]
# Out:
#              Id      Name  Year Gender State  Count
# 2208928  561496    Sophia  2014      F    CA   3162
# 2354744  707312      Noah  2014      M    CA   2761
# 2208929  561497  Isabella  2014      F    CA   2705
# 2354745  707313     Jacob  2014      M    CA   2692
# 2208930  561498      Emma  2014      F    CA   2662

# %%
ca_babies = states_babies.loc[states_babies['State'] == 'CA', :]

# %%
ca_babies
# Out:
#              Id      Name  Year Gender State  Count
# 2003450  356018      Mary  1910      F    CA    295
# 2003451  356019     Helen  1910      F    CA    239
# 2003452  356020   Dorothy  1910      F    CA    220
# 2003453  356021  Margaret  1910      F    CA    163
# 2003454  356022   Frances  1910      F    CA    134
# ...         ...       ...   ...    ...   ...    ...
# 2357658  710226    Zakary  2014      M    CA      5
# 2357659  710227   Zealand  2014      M    CA      5
# 2357660  710228      Ziad  2014      M    CA      5
# 2357661  710229    Zidane  2014      M    CA      5
# 2357662  710230     Ziyad  2014      M    CA      5
#
# [354213 rows x 6 columns]

# %%
def popular(s):
    """Receives s, a Pandas Series, containing baby names in order of highest count to lowest count.
    Returns the most popular names in s."""
    return s.iloc[0]

# %%
ca_group = ca_babies.sort_values('Count', ascending = False).groupby(['Year', 'Gender']).agg(popular)

# %%
ca_group
# Out:
#                  Id    Name State  Count
# Year Gender
# 1910 F       356018    Mary    CA    295
#      M       565480    John    CA    237
# 1911 F       356251    Mary    CA    390
#      M       565610    John    CA    214
# 1912 F       356502    Mary    CA    534
# ...             ...     ...   ...    ...
# 2012 M       701517   Jacob    CA   2971
# 2013 F       557545  Sophia    CA   3451
#      M       704421   Jacob    CA   2879
# 2014 F       561496  Sophia    CA   3162
#      M       707312    Noah    CA   2761
#
# [210 rows x 4 columns]

# %%
# get data file names
path = r'Exercise Files'
filenames = glob.glob(path + "/us_baby_names_*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
us_babies = pd.concat(dfs, ignore_index=True)

# %%
us_babies
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %%
us_anshul = us_babies.loc[us_babies['Name'] == 'Anshul', :]

# %%
us_anshul
# Out:
#               Id    Name  Year Gender  Count
# 1067207  1067208  Anshul  1989      M      6
# 1117906  1117907  Anshul  1991      M      5
# 1270960  1270961  Anshul  1997      M     10
# 1298177  1298178  Anshul  1998      M     11
# 1325092  1325093  Anshul  1999      M     17
# 1354774  1354775  Anshul  2000      M     16
# 1383589  1383590  Anshul  2001      M     26
# 1415786  1415787  Anshul  2002      M     14
# 1445280  1445281  Anshul  2003      M     23
# 1476133  1476134  Anshul  2004      M     33
# 1508404  1508405  Anshul  2005      M     36
# 1544438  1544439  Anshul  2006      M     15
# 1577602  1577603  Anshul  2007      M     24
# 1612129  1612130  Anshul  2008      M     27
# 1647353  1647354  Anshul  2009      M     23
# 1680844  1680845  Anshul  2010      M     31
# 1715532  1715533  Anshul  2011      M     22
# 1752035  1752036  Anshul  2012      M     11
# 1789148  1789149  Anshul  2013      M      6
# 1821093  1821094  Anshul  2014      M      7

# %%
us_anshul.plot.barh(x = 'Year', y = 'Count')
