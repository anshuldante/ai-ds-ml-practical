# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.array(range(-20, 21))

def f(x):
    return x ** 2 + 1

# %%
plt.plot(x, f(x))

plt.xlabel('x')
plt.ylabel('f(x)')

plt.axhline()
plt.axvline()

plt.show()

# %%
x = np.array(range(0,11))

def g(x):
    return x**2 + x

plt.plot(x, g(x))
plt.xlabel('x')
plt.ylabel('g(x)')

plt.axhline()
plt.axvline()

plt.show()

# %%
def h(x):
    if x != 0:
        return -(12/(2*x))**2
    
x = range(-100,101)

y = [h(a) for a in x]

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')

plt.axhline()
plt.axvline()

plt.show()

# %%
def i(x):
    if x >= 0:
        import numpy as np
        return 2 * np.sqrt(x)

    
x = range(-100,101)

y = [i(a) for a in x]

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')

plt.axhline()
plt.axvline()

plt.show()
