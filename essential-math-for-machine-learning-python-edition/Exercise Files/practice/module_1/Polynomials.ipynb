# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# 3𝑥3−4𝑥+5

# %%
df = pd.DataFrame({'x' : range(1,50)})

# %%
df['y'] = 3 * (df['x'] ** 3) - 4 * df['x'] + 5

# %%
plt.plot(df['x'], df['y'], 'blue')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline()
plt.axvline()
plt.show()
